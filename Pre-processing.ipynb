# %%
import pandas as pd

# %%
data = pd.read_csv("TRAIN_ver02.csv")

# %%
data
# Out:
#                  LID CHNL                                     SELLER  \
# 0       946681740815    B  Jpmorgan Chase Bank, National Association
# 1       921089628109    R                         Gmac Mortgage, Llc
# 2       738779422112    C                         Flagstar Bank, Fsb
# 3       615798070845    R                                      Other
# 4       345601060557    R                                      Other
# ...              ...  ...                                        ...
# 188737  562335400010    R                      Bank Of America, N.A.
# 188738  151011432193    C                     Suntrust Mortgage Inc.
# 188739  517753415065    R    Bishops Gate Residential Mortgage Trust
# 188740  948158851357    R                    Jpmorgan Chase Bank, Na
# 188741  603343045348    C                         Flagstar Bank, Fsb
#
#         ORIGRATE   ORIGUPB  ORIGTERM  LOANAGE  REMMNTHS  ADJRMTHS  OLTV  ...  \
# ...
